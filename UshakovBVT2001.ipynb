# %% [markdown]
# # 1.Print 'Hello HCIA'.

# %%
print('Hello HCIA')

# %% [markdown]
# # 2.Define two variables and calculate their sum.

# %%
a = 3
b = 5
sum = a + b
print(sum)

# %% [markdown]
# # 3.Define a list and replicate in three different ways.

# %%
list = [1,2,3,4]
print(list)
for i in range(lem(list)):
    print(list[i],end=' ')
for i in list:
    print(i, end=' ')

# %% [markdown]
# # 4.Define two lists and merge them together.

# %%
listOne =[1,2,3,4]
listTwo =[5,6,7,8]
defineList = listone + listTwo
print(defineList)

# %% [markdown]
# # 5. Get the last element of the list and print it.

# %%
listOne = [1,2,3,4]
lastIndex = listOne[-1]
print(lastIndex)

# %% [markdown]
# # 6.Define a tuple that contains only one element.

# %%
a =('tuple')

# %% [markdown]
# # 7.Define a three-line long string.

# %%
a =["n","d","f","e"]
b =["b","s"]
c =["w","d","c","v","v","d"]
dl = [len(a), len(b), len(c)]
if dl[0] > dl[1] and dl[0] > dl[2]:
    print(a)
elif dl[1] > dl[0] and dl[1] > dl[2]:
    print(b)
else:
    print(c)

# %% [markdown]
# # 8.Define a tuple and then use the 'for loop' to print all the elements.

# %%
tuple1 =(1,2,3,4,5,6)
for i in range(0,tuple1[-1]):
     print(tuple1[i])

# %% [markdown]
# # 9.Define a function to do Multiplication, such as Mul(8,6),and its output 48.

# %%
def mul(a,b):
     return int(a) * int(b)
print(mul(8,6))

# %% [markdown]
# # 10.Import numpy and use numpy to define an array, the its shape  is (5,5) and all its elements is 0.

# %%
import numpy as np
a = np.zeros((5,5))
print(a)

# %% [markdown]
# # 11.Import numpy and use numpy to define an array, the shape is (4,6) and all elements is 0.

# %%
import numpy as np
a = np.zeros((4,6))
print(a)

# %% [markdown]
# # 12.Use numpy.arrange() to generate an array of shape(15,), then modify the shape to(3,5).

# %%
import numpy as np
a = np.arange(15,)
a = a.reshape(3,5)
print(a)

# %% [markdown]
# # 13.Define two matrices, then calculate and print the result of their point multiplication.

# %%
import numpy as np
mat1 =([1,5,6],[3,4,8],[2,12,6])
mat2 =([3,4,6],[5,6,7],[5,14,7])
res = np.dot(mat1,mat2)
print(res)
